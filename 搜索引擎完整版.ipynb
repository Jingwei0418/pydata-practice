# %%
from lxml import etree
import requests
import time

url = 'http://bang.dangdang.com/books/fivestars/01.00.00.00.00.00-all-0-0-1-1 '

headers = {
            'Host': 'bang.dangdang.com',
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36',
        }

data = requests.get(url,headers=headers).text
s = etree.HTML(data)


items = s.xpath('//*[@id="sortRanking"]/div')

for item in items:
    book_url=item.xpath('./a/@href')
    item_name=item.xpath('./a/text()')
    if len(book_url)>0:
        href=book_url[0]
        item_title=item_name[0]
        a=href[41:46]
        print(item_title)
        with open(item_title[0:2]+'dangdang.txt','w',encoding='utf-8') as outputfile:
            for page in range(1,2):

                per_url= 'http://bang.dangdang.com/books/fivestars/{}.00.00.00.00-all-0-0-1-{}'.format(a,page)
                data2=requests.get(per_url).text
                f=etree.HTML(data2)

                try:
                    file=f.xpath('//ul[@class="bang_list clearfix bang_list_mode"]/li')
                    print('正在打印{}第{}页…………'.format(item_title,page))
                    time.sleep(2)

                    for book in file:
                        title=book.xpath('./div[@class="name"]/a/@title')[0]
                        author=book.xpath('string(./div[@class="publisher_info"][1])')
                        pinglun=book.xpath('./div[@class="star"]/a/text()')[0].strip('条评论')
                        wuxing=book.xpath('./div[@class="biaosheng"]/span/text()')[0].strip('次')
                        price_now=book.xpath('./div[@class="price"]/p/span[1]/text()')[0]
                        price_before=book.xpath('./div[@class="price"]/p/span[2]/text()')[0]
                        price_sale=book.xpath('./div[@class="price"]/p/span[3]/text()')[0]

                        try:
                            date=book.xpath('./div[@class="publisher_info"]/span/text()')[0]
                        except:
                            date='出版时间不详'

                        try:
                            company=book.xpath('./div[@class="publisher_info"][2]/a/text()')[0]
                        except:
                            company='出版社不详'

                        try:
                            price_e=book.xpath('./div[@class="price"]/p[@class="price_e"]/span/text()')[0]
                        except:
                            price_e="没有电子书"

                        outputfile.write('{},{},{},{},{},{},{},{},{},{}'.format(title,author,date,company,pinglun,wuxing,price_now,price_before,price_sale,price_e))
                        outputfile.write('\n')

                except:
                    pass
# Out:
# 童书
# 正在打印童书第1页…………
# 小说
# 正在打印小说第1页…………
# 中小学教辅
# 正在打印中小学教辅第1页…………
# 文学
# 正在打印文学第1页…………
# 成功/励志
# 正在打印成功/励志第1页…………
# 管理
# 正在打印管理第1页…………
# 外语
# 正在打印外语第1页…………
# 亲子/家教
# 正在打印亲子/家教第1页…………
# 历史
# 正在打印历史第1页…………
# 艺术
# 正在打印艺术第1页…………
# 考试
# 正在打印考试第1页…………
# 哲学/宗教
# 正在打印哲学/宗教第1页…………
# 青春文学
# 正在打印青春文学第1页…………
# 心理学
# 正在打印心理学第1页…………
# 教材
# 正在打印教材第1页…………
# 传记
# 正在打印传记第1页…………
# 计算机/网络
# 正在打印计算机/网络第1页…………
# 社会科学
# 正在打印社会科学第1页…………
# 古籍
# 正在打印古籍第1页…………
# 动漫/幽默
# 正在打印动漫/幽默第1页…………
# 医学
# 正在打印医学第1页…………
# 文化
# 正在打印文化第1页…………
# 保健/养生
# 正在打印保健/养生第1页…………
# 经济
# 正在打印经济第1页…………
# 政治/军事
# 正在打印政治/军事第1页…………
# 科普读物
# 正在打印科普读物第1页…………
# 投资理财
# 正在打印投资理财第1页…………
# 法律
# 正在打印法律第1页…………
# 烹饪/美食
# 正在打印烹饪/美食第1页…………
# 旅游/地图
# 正在打印旅游/地图第1页…………
# 育儿/早教
# 正在打印育儿/早教第1页…………
# 工业技术
# 正在打印工业技术第1页…………
# 孕产/胎教
# 正在打印孕产/胎教第1页…………
# 建筑
# 正在打印建筑第1页…………
# 体育/运动
# 正在打印体育/运动第1页…………
# 自然科学
# 正在打印自然科学第1页…………
# 家庭/家居
# 正在打印家庭/家居第1页…………
# 时尚/美妆
# 正在打印时尚/美妆第1页…………
# 两性关系
# 正在打印两性关系第1页…………
# 手工/DIY
# 正在打印手工/DIY第1页…………
# 休闲/爱好
# 正在打印休闲/爱好第1页…………
# 农业/林业
# 正在打印农业/林业第1页…………
# 工具书
# 正在打印工具书第1页…………
# 风水/占卜
# 正在打印风水/占卜第1页…………
# 英文原版书
# 正在打印英文原版书第1页…………

# %%
from lxml import etree
import requests
import time

url = 'http://bang.dangdang.com/books/fivestars/01.00.00.00.00.00-all-0-0-1-1'

headers = {
            'Host': 'bang.dangdang.com',
            'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36',
        }

data = requests.get(url,headers=headers).text
s = etree.HTML(data)

with open('英文dangdang.txt','w',encoding='utf-8') as outputfile:
    items = s.xpath('//*[@id="sortRanking"]/div[46]')

    for item in items:
        book_url=item.xpath('./a/@href')
        item_name=item.xpath('./a/text()')

        if len(book_url)>0:
            href=book_url[0]
            item_title=item_name[0]
            a=href[41:46]
            print(item_title)

            for page in range(1,2):

                per_url= 'http://bang.dangdang.com/books/fivestars/{}.00.00.00.00-all-0-0-1-{}'.format(a,page)
                data2=requests.get(per_url).text
                f=etree.HTML(data2)

                file=f.xpath('//ul[@class="bang_list clearfix bang_list_mode"]/li')
                print('正在打印{}第{}页…………'.format(item_title,page))
                time.sleep(2)

                for book in file:
                    title=book.xpath('./div[@class="name"]/a/@title')[0]
                    author=book.xpath('string(./div[@class="publisher_info"][1])')
                    pinglun=book.xpath('./div[@class="star"]/a/text()')[0].strip('条评论')
                    wuxing=book.xpath('./div[@class="biaosheng"]/span/text()')[0].strip('次')
                    price_now=book.xpath('./div[@class="price"]/p/span[1]/text()')[0]

                    try:
                        date=book.xpath('./div[@class="publisher_info"]/span/text()')[0]
                    except:
                        date='出版时间不详'

                    try:
                        company=book.xpath('./div[@class="publisher_info"][2]/a/text()')[0]
                    except:
                        company='出版社不详'

                    try:
                        price_e=book.xpath('./div[@class="price"]/p[@class="price_e"]/span/text()')[0]
                    except:
                        price_e="没有电子书"

                    outputfile.write('{},{},{},{},{},{},{},{}'.format(title,author,date,company,pinglun,wuxing,price_now,price_e))
                    outputfile.write('\n')
# Out:
# 英文原版书
# 正在打印英文原版书第1页…………
